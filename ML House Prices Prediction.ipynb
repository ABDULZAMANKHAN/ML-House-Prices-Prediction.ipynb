# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Vastu User\California_Houses.csv")
df.head()
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0            452600.0         8.3252          41        880           129
# 1            358500.0         8.3014          21       7099          1106
# 2            352100.0         7.2574          52       1467           190
# 3            341300.0         5.6431          52       1274           235
# 4            342200.0         3.8462          52       1627           280
#
#    Population  Households  Latitude  Longitude  Distance_to_coast  \
# 0         322         126     37.88    -122.23        9263.040773
# 1        2401        1138     37.86    -122.22       10225.733072
# 2         496         177     37.85    -122.24        8259.085109
# 3         558         219     37.85    -122.25        7768.086571
# 4         565         259     37.85    -122.25        7768.086571
#
#    Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# ...

# %%
df.columns
# Out:
# Index(['Median_House_Value', 'Median_Income', 'Median_Age', 'Tot_Rooms',
#        'Tot_Bedrooms', 'Population', 'Households', 'Latitude', 'Longitude',
#        'Distance_to_coast', 'Distance_to_LA', 'Distance_to_SanDiego',
#        'Distance_to_SanJose', 'Distance_to_SanFrancisco'],
#       dtype='object')

# %%
df.tail()
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
#        Population  Households  Latitude  Longitude  Distance_to_coast  \
# 20635         845         330     39.48    -121.09      162031.481121
# 20636         356         114     39.49    -121.21      160445.433537
# 20637        1007         433     39.43    -121.22      153754.341182
# 20638         741         349     39.43    -121.32      152005.022239
# 20639        1387         530     39.37    -121.24      146866.196892
#
#        Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Median_House_Value        20640 non-null  float64
#  1   Median_Income             20640 non-null  float64
#  2   Median_Age                20640 non-null  int64
#  3   Tot_Rooms                 20640 non-null  int64
#  4   Tot_Bedrooms              20640 non-null  int64
#  5   Population                20640 non-null  int64
#  6   Households                20640 non-null  int64
#  7   Latitude                  20640 non-null  float64
#  8   Longitude                 20640 non-null  float64
#  9   Distance_to_coast         20640 non-null  float64
#  10  Distance_to_LA            20640 non-null  float64
#  11  Distance_to_SanDiego      20640 non-null  float64
#  12  Distance_to_SanJose       20640 non-null  float64
# ...

# %%
df.isnull().sum()*100/len(df)
# Out:
# Median_House_Value          0.0
# Median_Income               0.0
# Median_Age                  0.0
# Tot_Rooms                   0.0
# Tot_Bedrooms                0.0
# Population                  0.0
# Households                  0.0
# Latitude                    0.0
# Longitude                   0.0
# Distance_to_coast           0.0
# Distance_to_LA              0.0
# Distance_to_SanDiego        0.0
# Distance_to_SanJose         0.0
# Distance_to_SanFrancisco    0.0
# dtype: float64

# %%
df.describe()
# Out:
#        Median_House_Value  Median_Income    Median_Age     Tot_Rooms  \
# count        20640.000000   20640.000000  20640.000000  20640.000000
# mean        206855.816909       3.870671     28.639486   2635.763081
# std         115395.615874       1.899822     12.585558   2181.615252
# min          14999.000000       0.499900      1.000000      2.000000
# 25%         119600.000000       2.563400     18.000000   1447.750000
# 50%         179700.000000       3.534800     29.000000   2127.000000
# 75%         264725.000000       4.743250     37.000000   3148.000000
# max         500001.000000      15.000100     52.000000  39320.000000
#
#        Tot_Bedrooms    Population    Households      Latitude     Longitude  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean     537.898014   1425.476744    499.539680     35.631861   -119.569704
# std      421.247906   1132.462122    382.329753      2.135952      2.003532
# ...

# %%
import matplotlib.pyplot as plt
# import seaborn as sns
df.hist(figsize=(21,12))
plt.tight_layout()
plt.show()

# %%
sns.histplot(data = df , x = 'Population' , binrange = (0,5000) , bins = 30)
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Count'>

# %%
sns.histplot(data = df , x = 'Tot_Rooms' , binrange = (0,7000) , bins = 30)
# Out:
# <AxesSubplot:xlabel='Tot_Rooms', ylabel='Count'>

# %%
sns.histplot(data = df , x = 'Tot_Bedrooms' , binrange = (0,3000) , bins = 30)
# Out:
# <AxesSubplot:xlabel='Tot_Bedrooms', ylabel='Count'>

# %%
sns.histplot(data = df , x = 'Households' , binrange = (0,3000) , bins = 30)
# Out:
# <AxesSubplot:xlabel='Households', ylabel='Count'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Median_Income')
# plt.show()
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Median_Income'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Median_Age')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Median_Age'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Tot_Rooms')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Tot_Rooms'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Tot_Bedrooms')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Tot_Bedrooms'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Population')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Population'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Households')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Households'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Latitude')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Latitude'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Longitude')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Longitude'>

# %%
df.columns
# Out:
# Index(['Median_House_Value', 'Median_Income', 'Median_Age', 'Tot_Rooms',
#        'Tot_Bedrooms', 'Population', 'Households', 'Latitude', 'Longitude',
#        'Distance_to_coast', 'Distance_to_LA', 'Distance_to_SanDiego',
#        'Distance_to_SanJose', 'Distance_to_SanFrancisco'],
#       dtype='object')

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Distance_to_coast')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Distance_to_coast'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Distance_to_LA')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Distance_to_LA'>

# %%
plt.figure(figsize = (10,8))
sns.regplot(data = df , x = 'Median_House_Value' , y = 'Distance_to_SanDiego')
# Out:
# <AxesSubplot:xlabel='Median_House_Value', ylabel='Distance_to_SanDiego'>

# %%
# Box Plot for numerical attribute
plt.figure(figsize=(22, 10))
sns.boxplot(data=df[['Median_Income', 'Median_Age', 'Tot_Rooms',
       'Tot_Bedrooms', 'Population', 'Households', 'Latitude', 'Longitude',]] , orient='V', palette='Set2')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def get_box_plot_data(labels, bp):
    rows_list = []

    for i in range(len(labels)):
        dict1 = {}
        dict1['label'] = labels[i]
        dict1['lower_whisker'] = bp['whiskers'][i*2].get_ydata()[1]
        dict1['lower_quartile'] = bp['boxes'][i].get_ydata()[1]
        dict1['median'] = bp['medians'][i].get_ydata()[1]
        dict1['upper_quartile'] = bp['boxes'][i].get_ydata()[2]
        dict1['upper_whisker'] = bp['whiskers'][(i*2)+1].get_ydata()[1]
        rows_list.append(dict1)

    return pd.DataFrame(rows_list)

# Assuming 'Tot_Rooms' is the column name in your DataFrame that you want to plot
Tot_Room = df['Tot_Rooms']
Tot_Bedroom = df['Tot_Bedrooms']
Population = df['Population']
Household = df['Households']
Income = df['Median_Income']
Age = df['Median_Age']

labels = ['Tot_Room', 'Tot_Bedroom', 'Population','Household','Income','Age']
bp = plt.boxplot([Tot_Room, Tot_Bedroom, Population,Household,Income,Age], labels=labels)
print(get_box_plot_data(labels, bp))
plt.show()
# Out:
#          label  lower_whisker  lower_quartile     median  upper_quartile  \
# 0     Tot_Room         2.0000       1447.7500  2127.0000      3148.00000
# 1  Tot_Bedroom         1.0000        295.0000   435.0000       647.00000
# 2   Population         3.0000        787.0000  1166.0000      1725.00000
# 3    Household         1.0000        280.0000   409.0000       605.00000
# 4       Income         0.4999          2.5634     3.5348         4.74325
# 5          Age         1.0000         18.0000    29.0000        37.00000
#
#    upper_whisker
# 0      5694.0000
# 1      1175.0000
# 2      3132.0000
# 3      1092.0000
# 4         8.0113
# 5        52.0000

# %%
df.shape
# Out:
# (20640, 14)

# %%
df.columns
# Out:
# Index(['Median_House_Value', 'Median_Income', 'Median_Age', 'Tot_Rooms',
#        'Tot_Bedrooms', 'Population', 'Households', 'Latitude', 'Longitude',
#        'Distance_to_coast', 'Distance_to_LA', 'Distance_to_SanDiego',
#        'Distance_to_SanJose', 'Distance_to_SanFrancisco'],
#       dtype='object')

# %%
df.loc[df['Tot_Rooms']>5694 , 'Tot_Rooms'] =5694
print(df['Tot_Rooms'].max())
# Out:
# 5694

# %%
df.loc[df['Tot_Bedrooms']>1175 , 'Tot_Bedrooms'] = 1175
print(df['Tot_Bedrooms'].max())
# Out:
# 1175

# %%
df.loc[df['Population']>3132 ,'Population'] = 3132
print(df['Population'].max())
# Out:
# 3132

# %%
df.loc[df['Households']>1092 , 'Households'] = 1092
print(df['Households'].max())
# Out:
# 1092

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Median_House_Value' , axis = 1)
X
# Out:
#        Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  Population  \
# 0             8.3252          41        880           129         322
# 1             8.3014          21       5694          1106        2401
# 2             7.2574          52       1467           190         496
# 3             5.6431          52       1274           235         558
# 4             3.8462          52       1627           280         565
# ...              ...         ...        ...           ...         ...
# 20635         1.5603          25       1665           374         845
# 20636         2.5568          18        697           150         356
# 20637         1.7000          17       2254           485        1007
# 20638         1.8672          18       1860           409         741
# 20639         2.3886          16       2785           616        1387
#
#        Households  Latitude  Longitude  Distance_to_coast  Distance_to_LA  \
# ...

# %%
y = df['Median_House_Value']
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: Median_House_Value, Length: 20640, dtype: float64

# %%
cols = ['Median_Income', 'Median_Age', 'Tot_Rooms',
       'Tot_Bedrooms', 'Population', 'Households', 'Latitude', 'Longitude',
       'Distance_to_coast', 'Distance_to_LA', 'Distance_to_SanDiego',
       'Distance_to_SanJose', 'Distance_to_SanFrancisco']

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
X[cols] = st.fit_transform(X[cols])
X
# Out:
#        Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  Population  \
# 0           2.344766    0.982143  -1.117598     -1.299864   -1.325821
# 1           2.332238   -0.607019   2.328059      2.098242    1.389936
# 2           1.782699    1.856182  -0.697448     -1.087700   -1.098528
# 3           0.932968    1.856182  -0.835590     -0.931185   -1.017539
# 4          -0.012881    1.856182  -0.582927     -0.774670   -1.008395
# ...              ...         ...        ...           ...         ...
# 20635      -1.216128   -0.289187  -0.555728     -0.447729   -0.642637
# 20636      -0.691593   -0.845393  -1.248582     -1.226824   -1.281408
# 20637      -1.142593   -0.924851  -0.134147     -0.061659   -0.431019
# 20638      -1.054583   -0.845393  -0.416156     -0.325995   -0.778490
# 20639      -0.780129   -1.004309   0.245920      0.393972    0.065368
#
#        Households  Latitude  Longitude  Distance_to_coast  Distance_to_LA  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import cross_val_score
import numpy as np
import matplotlib.pyplot as plt

model_df = {}

def model_val(model, X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    print(f"{model} Mean Absolute Error on train data: {mean_absolute_error(y_train, y_train_pred)}")
    print(f"{model} Mean Absolute Error on test data: {mean_absolute_error(y_test, y_test_pred)}")
    
    mse_train = mean_squared_error(y_train, y_train_pred)
    mse_test = mean_squared_error(y_test, y_test_pred)
    print(f"{model} Mean Squared Error on train data: {mse_train}")
    print(f"{model} Mean Squared Error on test data: {mse_test}")
    
    rmse_train = np.sqrt(mse_train)
    rmse_test = np.sqrt(mse_test)
    print(f"{model} Root Mean Squared Error on train data: {rmse_train}")
    print(f"{model} Root Mean Squared Error on test data: {rmse_test}")
    
    r2_train = r2_score(y_train, y_train_pred)
    r2_test = r2_score(y_test, y_test_pred)
    print(f"{model} R-squared on train data: {r2_train}")
    print(f"{model} R-squared on test data: {r2_test}")
    
    n = len(X_train)
    p = X_train.shape[1]
    adj_r2_train = 1 - (1 - r2_train) * (n - 1) / (n - p - 1)
    adj_r2_test = 1 - (1 - r2_test) * (n - 1) / (n - p - 1)
    print(f"{model} Adjusted R-squared on train data: {adj_r2_train}")
    print(f"{model} Adjusted R-squared on test data: {adj_r2_test}")
    
    score = cross_val_score(model, X, y, cv=5, scoring='neg_mean_squared_error')
    print(f"{model} Avg val score (neg_mean_squared_error) is {np.mean(score)}")
    model_df[(model)] = -np.mean(score)
    
    # Plot predicted vs actual values
    plt.figure(figsize=(8, 4))
    #plt.scatter(y_train, y_train_pred, label='Train')
    plt.scatter(y_train, y_train_pred, label='Train')
    plt.scatter(y_test, y_test_pred, label='Test')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Actual vs Predicted Values')
    plt.legend()
    plt.show()

# %%
model_df
# Out:
# {LinearRegression(): 5217320290.988256,
#  Lasso(alpha=0.1): 5190629080.057128,
#  Ridge(alpha=0.1): 5214825916.584582,
#  Lasso(alpha=0.01): 5190886095.936422,
#  Ridge(alpha=0.01): 5217069438.84651,
#  Lasso(alpha=0.1): 5190629080.057128,
#  Ridge(alpha=0.1): 5214825916.584582,
#  Lasso(alpha=1): 5188065484.911249,
#  Ridge(alpha=1): 5193705024.6706295,
#  Lasso(alpha=10): 5163086148.955492,
#  Ridge(alpha=10): 5062229878.346326,
#  Lasso(alpha=10): 5163086148.955492,
#  Ridge(alpha=10): 5062229878.346326}

# %%
from sklearn.linear_model import LinearRegression
linear_regression = LinearRegression()
model_val(linear_regression, X, y)
# Out:
# LinearRegression() Mean Absolute Error on train data: 48788.769535435145
# LinearRegression() Mean Absolute Error on test data: 48796.40565220526
# LinearRegression() Mean Squared Error on train data: 4460638515.7233
# LinearRegression() Mean Squared Error on test data: 4443868169.909527
# LinearRegression() Root Mean Squared Error on train data: 66788.01176650867
# LinearRegression() Root Mean Squared Error on test data: 66662.34446754424
# LinearRegression() R-squared on train data: 0.6670409861093429
# LinearRegression() R-squared on test data: 0.661429914144785
# LinearRegression() Adjusted R-squared on train data: 0.6667411061605707
# LinearRegression() Adjusted R-squared on test data: 0.6611249805770895
# LinearRegression() Avg val score (neg_mean_squared_error) is -5217320290.988256

# %%
alphas = [10]  # Example alpha values, you can modify this list

for alpha in alphas:
    # L1 Penalty (Lasso)
    lasso_model = Lasso(alpha=alpha)
    print(f"Lasso with alpha={alpha}")
    model_val(lasso_model, X, y)

    # L2 Penalty (Ridge)
    ridge_model = Ridge(alpha=alpha)
    print(f"Ridge with alpha={alpha}")
    model_val(ridge_model, X, y)
# Out:
# Lasso with alpha=10
# Lasso(alpha=10) Mean Absolute Error on train data: 48793.6990548051
# Lasso(alpha=10) Mean Absolute Error on test data: 48803.86691222159
# Lasso(alpha=10) Mean Squared Error on train data: 4460815160.049158
# Lasso(alpha=10) Mean Squared Error on test data: 4443336150.66621
# Lasso(alpha=10) Root Mean Squared Error on train data: 66789.33417881299
# Lasso(alpha=10) Root Mean Squared Error on test data: 66658.35394506986
# Lasso(alpha=10) R-squared on train data: 0.6670278007054284
# Lasso(alpha=10) R-squared on test data: 0.6614704477056378
# Lasso(alpha=10) Adjusted R-squared on train data: 0.6667279088812058
# Lasso(alpha=10) Adjusted R-squared on test data: 0.6611655506445441
# ...
